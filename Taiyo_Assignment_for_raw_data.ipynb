# %%
import requests
import pandas as pd
from prettytable import PrettyTable
import json

# %%
pip install PrettyTable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\91824\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
#Creating pretty table object
tableobj = PrettyTable()
KeyVal = "6ab88d54f5c64cf7a641b030bc1eebbd"

# %%
api_endpoint = "https://newsapi.org/v2/top-headlines?country=us&apiKey=6ab88d54f5c64cf7a641b030bc1eebbd"
api_endpoint
# Out:
# 'https://newsapi.org/v2/top-headlines?country=us&apiKey=6ab88d54f5c64cf7a641b030bc1eebbd'

# %%
json_data = requests.get(api_endpoint).json()

# %%
raw_data = requests.get(api_endpoint).json()

# %%
#data extracted from https://newsapi.org/s/google-news-api as mentioned in one of the links given in the assignment question
raw_data  #Data in JSON Format
# Out:
# {'status': 'ok',
#  'totalResults': 20,
#  'articles': [{'source': {'id': None, 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Hong Kong: What is China's 'patriot' plan for electoral reform? - BBC News",
#    'description': 'Aiming to tighten control over Hong Kong, China wants only "patriots" to run for office.',
#    'url': 'https://www.bbc.com/news/world-asia-china-56534040',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/125FD/production/_117716257_797d34e2-572e-4dec-993c-a391ff5c4a01.jpg',
#    'publishedAt': '2021-03-30T05:17:27Z',
#    'content': 'image captionHong Kong\'s flag, flying in line with China\'s banner\r\nIn its latest move to tighten control over Hong Kong, China is pushing for a controversial "patriot" plan to reform the city\'s elect… [+3133 chars]'},
#   {'source': {'id': None, 'name': 'ESPN'},
#    'author': 'ESPN',
# ...

# %%
import pandas as pd
import json

# %%
json.dumps(raw_data)
# Out:
# '{"status": "ok", "totalResults": 20, "articles": [{"source": {"id": null, "name": "BBC News"}, "author": "https://www.facebook.com/bbcnews", "title": "Hong Kong: What is China\'s \'patriot\' plan for electoral reform? - BBC News", "description": "Aiming to tighten control over Hong Kong, China wants only \\"patriots\\" to run for office.", "url": "https://www.bbc.com/news/world-asia-china-56534040", "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/125FD/production/_117716257_797d34e2-572e-4dec-993c-a391ff5c4a01.jpg", "publishedAt": "2021-03-30T05:17:27Z", "content": "image captionHong Kong\'s flag, flying in line with China\'s banner\\r\\nIn its latest move to tighten control over Hong Kong, China is pushing for a controversial \\"patriot\\" plan to reform the city\'s elect\\u2026 [+3133 chars]"}, {"source": {"id": null, "name": "ESPN"}, "author": "ESPN", "title": "Will top seeds Gonzaga and Michigan join Houston and Baylor in the Final Four? - ESPN", "description": "H
# ...

# %%
df = pd.DataFrame(raw_data)    #Data in csv format(structured and clean)

# %%
df
# Out:
#    status  totalResults                                           articles
# 0      ok            20  {'source': {'id': None, 'name': 'BBC News'}, '...
# 1      ok            20  {'source': {'id': None, 'name': 'ESPN'}, 'auth...
# 2      ok            20  {'source': {'id': None, 'name': 'Daily Beast'}...
# 3      ok            20  {'source': {'id': None, 'name': 'Investor's Bu...
# 4      ok            20  {'source': {'id': None, 'name': 'KCRA Sacramen...
# 5      ok            20  {'source': {'id': None, 'name': 'OregonLive'},...
# 6      ok            20  {'source': {'id': 'the-hill', 'name': 'The Hil...
# 7      ok            20  {'source': {'id': None, 'name': 'Fox Business'...
# 8      ok            20  {'source': {'id': None, 'name': 'Rolling Stone...
# 9      ok            20  {'source': {'id': 'engadget', 'name': 'Engadge...
# 10     ok            20  {'source': {'id': None, 'name': 'CNET'}, 'auth...
# ...

# %%
print('# of transactions in original data:' +str(len(df.index)))
# Out:
# # of transactions in original data:20

# %%
#Checking if there are null values in the dataframe
df.isnull()
# Out:
#     status  totalResults  articles
# 0    False         False     False
# 1    False         False     False
# 2    False         False     False
# 3    False         False     False
# 4    False         False     False
# 5    False         False     False
# 6    False         False     False
# 7    False         False     False
# 8    False         False     False
# 9    False         False     False
# 10   False         False     False
# 11   False         False     False
# 12   False         False     False
# 13   False         False     False
# 14   False         False     False
# 15   False         False     False
# 16   False         False     False
# 17   False         False     False
# 18   False         False     False
# 19   False         False     False

# %%
df.head()
# Out:
#   status  totalResults                                           articles
# 0     ok            20  {'source': {'id': None, 'name': 'BBC News'}, '...
# 1     ok            20  {'source': {'id': None, 'name': 'ESPN'}, 'auth...
# 2     ok            20  {'source': {'id': None, 'name': 'Daily Beast'}...
# 3     ok            20  {'source': {'id': None, 'name': 'Investor's Bu...
# 4     ok            20  {'source': {'id': None, 'name': 'KCRA Sacramen...
